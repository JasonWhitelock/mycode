# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy

# Define the data we want to plot. Using numpy's linspace function, we are creating an array of 70 values from -2pi to 2pi
X = np.linspace(-2 * np.pi, 2 * np.pi, 70, endpoint=True)
F1 = np.sin(2* X)
F2 = (2*X**5 + 4*X**4 - 4.8*X**3 + 1.2*X**2 + X + 1)*np.exp(-X**2)

fig, ax = plt.subplots()

# Using 'none' as the color parameter will make the spines invisible:
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

# Reposition the bottom spine to y=0:
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))

# Reposition left spine to x= 0:
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))


# own

#figure, axes = plt.subplots()
circlehead = plt.Circle((0.5, 0.5), 0.3, facecolor= "yellow")
circleleft = plt.Circle((0.4, 0.6), 0.04)
circlelefti = plt.Circle((0.408, 0.6), 0.009, fill=False)

circleright = plt.Circle((0.6, 0.6), 0.04)
circlerighti = plt.Circle((0.608, 0.6), 0.009, fill=False)
#thesmile = plt.plot([0.4, 0.44, 0.5, 0.56, 0.6], [0.42, 0.4, 0.38, 0.4, 0.42])

#ax.set_aspect(1)
ax.add_artist(circlehead)
ax.add_artist(circleleft)
ax.add_artist(circleright)
ax.add_artist(circlelefti)
ax.add_artist(circlerighti)
#ax.add_artist(thesmile)
#ax.plot([0.4, 0.44, 0.5, 0.56, 0.6], [0.42, 0.4, 0.38, 0.4, 0.42])
#ax.plot(X, thesmile)
plt.title('Smile')

# ax.plot(X, F1, X, F2)
points = np.array([
  [0.4, 0.42],
  [0.44, 0.4],
  [0.5, 0.38],
  [0.56, 0.4],
  [0.6, 0.42]
])

simplices = scipy.spatial.Delaunay(points).simplices

# plt.triplot(points[:, 0], points[:, 1], simplices)
# plt.scatter(points[:, 0], points[:, 1], color='r')

plt.show()
