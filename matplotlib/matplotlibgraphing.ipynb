# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the data we want to plot. Using numpy's linspace function, we are creating an array of 70 values from -2pi to 2pi
X = np.linspace(-2 * np.pi, 2 * np.pi, 70, endpoint=True)
F1 = np.sin(2* X)
F2 = (2*X**5 + 4*X**4 - 4.8*X**3 + 1.2*X**2 + X + 1)*np.exp(-X**2)

fig, ax = plt.subplots()

# Using 'none' as the color parameter will make the spines invisible:
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

# Reposition the bottom spine to y=0:
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))

# Reposition left spine to x= 0:
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

ax.plot(X, F1, X, F2)

plt.show()

# %%
fig, ax = plt.subplots()

# Get the default xticks and labels from the ax object created above
xticks = ax.get_xticks()
xticklabels = ax.get_xticklabels()
print(xticks, xticklabels)

# Print out the first 6 xtick labels
for i in range(6):
    print(xticklabels[i])

yticks = ax.get_yticks()
print(yticks)
# Out:
# [0.  0.2 0.4 0.6 0.8 1. ] [Text(0.0, 0, '0.0'), Text(0.2, 0, '0.2'), Text(0.4, 0, '0.4'), Text(0.6000000000000001, 0, '0.6'), Text(0.8, 0, '0.8'), Text(1.0, 0, '1.0')]
# Text(0.0, 0, '0.0')
# Text(0.2, 0, '0.2')
# Text(0.4, 0, '0.4')
# Text(0.6000000000000001, 0, '0.6')
# Text(0.8, 0, '0.8')
# Text(1.0, 0, '1.0')
# [0.  0.2 0.4 0.6 0.8 1. ]

# %%
fig, ax = plt.subplots()

ax.set_xticks([7, 13, 19, 33, 42])
# Out:
# [<matplotlib.axis.XTick at 0x7f1b259974c0>,
#  <matplotlib.axis.XTick at 0x7f1b259ed6f0>,
#  <matplotlib.axis.XTick at 0x7f1b259ed360>,
#  <matplotlib.axis.XTick at 0x7f1b25824fa0>,
#  <matplotlib.axis.XTick at 0x7f1b25825a50>]

# %%
fig, ax = plt.subplots()

ax.set_xticks([7, 13, 19, 33, 42])
ax.set_xticklabels(['Berlin', 'Frankfurt', 'Hamburg', 'Munich', 'Zurich'])
# Out:
# [Text(7, 0, 'Berlin'),
#  Text(13, 0, 'Frankfurt'),
#  Text(19, 0, 'Hamburg'),
#  Text(33, 0, 'Munich'),
#  Text(42, 0, 'Zurich')]

# %%
X = np.linspace(-2 * np.pi, 2 * np.pi, 70, endpoint=True)
X = np.linspace(-2 * np.pi, 2 * np.pi, 70, endpoint=True)
F1 = np.sin(X**2)
F2 = X * np.sin(X)

fig, ax = plt.subplots()

# Make the top and right spines invisible:
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
# Reposition bottom spine to y=0:
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
# Reposition left spine to x=0:
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

# Manually set xticks to factors of pi
ax.set_xticks( [-6.28, -3.14, 3.14, 6.28])
ax.set_yticks([-3, -1, 0, +1, 3])
ax.plot(X, F1)
ax.plot(X, F2)

plt.show()

# %%
X = np.linspace(-2 * np.pi, 2 * np.pi, 100)
F1 = np.sin(X)
F2 = (3 * np.sin(X))+1
fig, ax = plt.subplots()

ax.xaxis.set_major_locator(plt.MultipleLocator(np.pi / 2))

ax.plot(X, F1, X, F2)

plt.show()

# %%
import matplotlib.ticker as ticker

X = np.linspace(-2 * np.pi, 2 * np.pi, 100)
F1 = np.tan(-X)
F2 = 30 * np.sin(X)
F3 = 20 * np.cos(X+45)
fig, ax = plt.subplots()

positions = [np.pi / 2 * x for x in range(-4, 5)]
labels = [r'$-2\pi$', r'$-\frac{3\pi}{2}$', r'$-\pi$', 
                    r'$-\frac{\pi}{2}$', 0, r'$\frac{\pi}{2}$', 
                    r'$+\pi$', r'$\frac{3\pi}{2}$', r'$+2\pi$']
ax.xaxis.set_major_locator(ticker.FixedLocator(positions))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(labels))


ax.plot(X, F1, X, F2, X, F3)

plt.show()

# %%
X = np.linspace(-2 * np.pi, 2 * np.pi, 170, endpoint=True)
F1 = np.sin(X**3 / 2)

fig, ax = plt.subplots()

positions = [np.pi / 2 * x for x in range(-4, 5)]
labels = [r'$-2\pi$', r'$-\frac{3\pi}{2}$', r'$-\pi$', 
                    r'$-\frac{\pi}{2}$', 0, r'$\frac{\pi}{2}$', 
                    r'$+\pi$', r'$\frac{3\pi}{2}$', r'$+2\pi$']
ax.xaxis.set_major_locator(ticker.FixedLocator(positions))
ax.xaxis.set_major_formatter(ticker.FixedFormatter(labels))


for xtick in ax.get_xticklabels():
    xtick.set_fontsize(18)
    xtick.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.7 ))

for ytick in ax.get_yticklabels():
    ytick.set_fontsize(14)
    ytick.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.7 ))

ax.plot(X, F1, label="$sin(x)$")

ax.legend(loc='lower left')

plt.show()
